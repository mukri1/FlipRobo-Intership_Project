# %%
import numpy as np
import pandas as pd

# %%
from  bs4 import BeautifulSoup
import requests

# %%
page1 = requests.get("https://en.wikipedia.org/wiki/Main_Page")

# %%
soup = BeautifulSoup(page1.content)

# %%
header1 = soup.find_all(['h1','h2','h3','h4','h5','h6'])

# %%
header1
# Out:
# [<h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none">Main Page</h1>,
#  <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>,
#  <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>,
#  <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>,
# ...

# %% [markdown]
# # Q2:Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.?

# %%
page2 = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc")

# %%
page2
# Out:
# <Response [200]>

# %%
soup1 = BeautifulSoup(page2.content)

# %%
soup1
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb "Top 100"
# (Sorted by IMDb Rating Descending) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# ...

# %%
for i in movie_data:
    name = i.h3.a.text
    movie_names.append(name)

# %%
for i in movie_data:
    year_of_release = i.h3.find('span',class_="lister-item-year text-muted unbold").text.replace('(',"").replace(')',"")
    year.append(year_of_release)

# %%
for i in movie_data:
    rating = rating = i.find('div',class_ = "inline-block ratings-imdb-rating").text.replace("\n","")
    ratings.append(rating)

# %%
imdb = pd.DataFrame({})

# %%
imdb['Movie_name']=movie_names
imdb['year']=year_of_release
imdb['rating'] =ratings

# %%
page3 = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&start=51&ref_=adv_nxt")

# %%
page3
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(page3.content)

# %%
soup2
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb "Top 100"
# (Sorted by IMDb Rating Descending) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# ...

# %%
movie_data1 = soup2.find_all('div',class_="lister-item mode-advanced")

# %%
year1 = []
movie_names1 = []
ratings1 = []

# %%
for i in movie_data1:
    name1 = i.h3.a.text
    movie_names1.append(name1)

# %%
for i in movie_data1:
    year_of_release1 = i.h3.find('span',class_="lister-item-year text-muted unbold").text.replace('(',"").replace(')',"")
    year1.append(year_of_release1)

# %%
for i in movie_data1:
    rating1 = i.find('div',class_ = "inline-block ratings-imdb-rating").text.replace("\n","")
    ratings1.append(rating1)

# %%
imdb1 = pd.DataFrame({})
imdb1['Movie_name']=movie_names1
imdb1['year']=year_of_release1
imdb1['rating'] =ratings1

# %%
frames = [imdb,imdb1]
result = pd.concat(frames

# %% [markdown]
# # Q3: Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Yearof release) and make data frame

# %%
from  bs4 import BeautifulSoup
import requests

# %%
page4 = requests.get("https://www.imdb.com/india/top-rated-indian-movies/")
soup3 = BeautifulSoup(page4.content)

# %%
soup3
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <style>
#             body#styleguide-v2 #root {
#                 box-shadow: none;
#             }
#         </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top Rated Indian Movies - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
# ...

# %%
name = soup3.find_all("td",class_="titleColumn")

# %%
name
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt8176054/" title="Mari Selvaraj (dir.), Kathir, Anandhi">Pariyerum Perumal</a>
#  <span class="secondaryInfo">(2018)</span>
#  </td>,
#  <td class="titleColumn">
#        2.
#        <a href="/title/tt0093603/" title="Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan">Nayakan</a>
#  <span class="secondaryInfo">(1987)</span>
#  </td>,
#  <td class="titleColumn">
#        3.
#        <a href="/title/tt15097216/" title="T.J. Gnanavel (dir.), Suriya, Lijo Mol Jose">Jai Bhim</a>
#  <span class="secondaryInfo">(2021)</span>
#  </td>,
#  <td class="titleColumn">
#        4.
#        <a href="/title/tt0367495/" title="Sundar C. (dir.), Kamal Haasan, Madhavan">Anbe Sivam</a>
#  <span class="secondaryInfo">(2003)</span>
#  </td>,
#  <td class="titleColumn">
#        5.
#        <a href="/title/tt7391996/" title="Venkatesh Maha (dir.), Radha Bessy, Subba Rao Vepada">C/o Kancharapalem</a>
# ...

# %%
movies_name = []
for i in name:
    for j in i.find_all("a"):
        movies_name.append(j.text)

# %%
movies_name
# Out:
# ['Pariyerum Perumal',
#  'Nayakan',
#  'Jai Bhim',
#  'Anbe Sivam',
#  'C/o Kancharapalem',
#  'Kireedam',
#  'Manichitrathazhu',
#  'Golmaal',
#  'Apur Sansar',
#  'Natsamrat',
#  'Thevar Magan',
#  '#Home',
#  'Kumbalangi Nights',
#  'Black Friday',
#  'Visaaranai',
#  'Jersey',
#  'Sardar Udham',
#  'Soorarai Pottru',
#  'Pather Panchali',
#  '3 Idiots',
#  'Asuran',
#  'Kaithi',
#  'Sarpatta Parambarai',
#  'Thalapathi',
#  'Taare Zameen Par',
#  '96',
#  'Devasuram',
#  'Drishyam 2',
#  'Dangal',
#  'Peranbu',
#  'Vada Chennai',
#  'Chithram',
#  'Aparajito',
#  'Jaane Bhi Do Yaaro',
#  'Pyaasa',
#  'Thani Oruvan',
#  'Guide',
#  'Spadikam',
#  'Iruvar',
#  'Agent Sai Srinivasa Athreya',
#  'Ratsasan',
#  'Kannathil Muthamittal',
#  'Chupke Chupke',
#  'Mahanati',
#  'Super Deluxe',
#  'Aruvi',
#  'Pudhu Pettai',
#  'Drishyam',
#  'Oru Vadakkan Veeragatha',
#  'Khosla Ka Ghosla!',
#  'Anniyan',
#  'Vikram Vedha',
#  'Premam',
#  'Tumbbad',
#  'Kaakkaa Muttai',
#  'Mudhalvan',
# ...

# %% [markdown]
# # Q4 Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vbp

# %%
from bs4 import BeautifulSoup
import requests

# %%
pag13=requests.get("https://meesho.com/bags-ladies/pl/p7vbp")

# %%
pag13
# Out:
# <Response [200]>

# %%
soup13=BeautifulSoup(pag13.content)

# %%
soup13
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-2"></script><script async="">
#               window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'UA-113318580-2', {
#                 page_path: window.location.pathname,
#               });
#           </script><script async="">
#           (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-WCJQFLD');
# ...

# %%
prod_name=soup13.find('p',class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS")

# %%
prod_name.text
# Out:
# 'Elegant Fashionable Women Handbags'

# %%
price12=soup13.find('div',class_="Card__BaseCard-sc-b3n78k-0 iLPHgK NewProductCard__PriceRow-sc-j0e7tu-5 eyya-Dr NewProductCard__PriceRow-sc-j0e7tu-5 eyya-Dr")

# %%
price.text
# Out:
# '₹ 299'

# %%
discount=soup13.find('div',class_="Card__BaseCard-sc-b3n78k-0 iJCKg NewProductCard__DiscountRow-sc-j0e7tu-15 kUcVjG NewProductCard__DiscountRow-sc-j0e7tu-15 kUcVjG")

# %%
discount.text
# Out:
# '₹82 discount on 1st order'

# %% [markdown]
# # Q5:Write a python program to scrape cricket rankings from ‘www.icccricket.com’ i)Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.#

# %%
page6 = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
page6
# Out:
# <Response [200]>

# %%
soup6= BeautifulSoup(page6.content)
Team_data = soup6.find_all('div',class_="rankings-block__container full rankings-table")

Team_Name = []

# %%
spans = soup6.find_all("span",class_="u-hide-phablet")
for span in spans:
    
    Team_Name.append(span.text)

# %%
Team_Name
# Out:
# ['New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan',
#  'New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan',
#  'Netherlands',
#  'Ireland',
#  'Scotland',
#  'Zimbabwe',
#  'Oman',
#  'Nepal',
#  'UAE',
#  'Namibia',
#  'United States',
#  'Papua New Guinea',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Team_Name = Team_Name[:10]

# %%
Team_Name
# Out:
# ['New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan']

# %%
Points = []
spans = soup6.find_all("td",class_="table-body__cell u-center-text")
for span in spans:
    print(span.text)
    Points.append(span.text)
# Out:
# 32
# 3,793
# 28
# 3,244
# 32
# 3,624
# 25
# 2,459
# 27
# 2,524
# 30
# 2,740
# 30
# 2,523
# 32
# 2,657
# 17
# 1,054
# 7
# 336
# 25
# 1,145
# 10
# 452
# 20
# 764
# 16
# 566
# 11
# 330
# 9
# 190
# 8
# 167
# 14
# 232
# 13
# 0

# %%
Matches = Points[0::2]

# %%
Matches = Matches[:9]

# %%
Matches
# Out:
# ['32', '28', '32', '25', '27', '30', '30', '32', '17']

# %%
Points = Points[1::2]

# %%
Points = Points[:9]

# %%
Points
# Out:
# ['3,793',
#  '3,244',
#  '3,624',
#  '2,459',
#  '2,524',
#  '2,740',
#  '2,523',
#  '2,657',
#  '1,054']

# %%
Ratings = []
spans = soup6.find_all("td",class_="table-body__cell u-text-right rating")
for span in spans:
    print(span.text)
    Ratings.append(span.text)
# Out:
# 119
# 116
# 113
# 98
# 93
# 91
# 84
# 83
# 62
# 48
# 46
# 45
# 38
# 35
# 30
# 21
# 21
# 17
# 0

# %%
Ratings = Ratings[:9]

# %%
Ratings
# Out:
# ['119', '116', '113', '98', '93', '91', '84', '83', '62']

# %%
Team_Name,Matches,Points,Ratings
# Out:
# (['New Zealand',
#   'England',
#   'Australia',
#   'India',
#   'South Africa',
#   'Pakistan',
#   'Bangladesh',
#   'West Indies',
#   'Sri Lanka',
#   'Afghanistan'],
#  ['32', '28', '32', '25', '27', '30', '30', '32', '17'],
#  ['3,793',
#   '3,244',
#   '3,624',
#   '2,459',
#   '2,524',
#   '2,740',
#   '2,523',
#   '2,657',
#   '1,054'],
#  ['119', '116', '113', '98', '93', '91', '84', '83', '62'])

# %%
Matches.insert(0, 17)
print(Matches)
# Out:
# [17, '32', '28', '32', '25', '27', '30', '30', '32', '17']

# %%
Points.insert(0, 2052)
print(Points)
# Out:
# [2052, '3,793', '3,244', '3,624', '2,459', '2,524', '2,740', '2,523', '2,657', '1,054']

# %%
Ratings.insert(0,121)
print(Ratings)
# Out:
# [121, '119', '116', '113', '98', '93', '91', '84', '83', '62']

# %%
Team_Name,Matches,Points,Ratings
# Out:
# (['New Zealand',
#   'England',
#   'Australia',
#   'India',
#   'South Africa',
#   'Pakistan',
#   'Bangladesh',
#   'West Indies',
#   'Sri Lanka',
#   'Afghanistan'],
#  [17, '32', '28', '32', '25', '27', '30', '30', '32', '17'],
#  [2052,
#   '3,793',
#   '3,244',
#   '3,624',
#   '2,459',
#   '2,524',
#   '2,740',
#   '2,523',
#   '2,657',
#   '1,054'],
#  [121, '119', '116', '113', '98', '93', '91', '84', '83', '62'])

# %%
import pandas as pd
ICC_data1 = pd.DataFrame({})
ICC_data1['Team_Name']= Team_Name
ICC_data1['Matches']= Matches
ICC_data1['Points'] = Points
ICC_data1['Ratings'] = Ratings

# %%
ICC_data1
# Out:
#       Team_Name Matches Points Ratings
# 0   New Zealand      17   2052     121
# 1       England      32  3,793     119
# 2     Australia      28  3,244     116
# 3         India      32  3,624     113
# 4  South Africa      25  2,459      98
# 5      Pakistan      27  2,524      93
# 6    Bangladesh      30  2,740      91
# 7   West Indies      30  2,523      84
# 8     Sri Lanka      32  2,657      83
# 9   Afghanistan      17  1,054      62

# %% [markdown]
# # ii)Top 10 ODI Batsmen in men along with the records of their team and rating

# %%
page7 = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")

soup7 = BeautifulSoup(page7.content)
Batsmen_data = soup7.find_all('div',class_="l-sticky-side-nav__content")

# %%
Batsmen_Name = []
spans = soup7.find_all("td",class_="table-body__cell name")
for span in spans:
    print(span.text)
    Batsmen_Name.append(span.text)
# Out:
# Virat Kohli
#
#
# Rohit Sharma
#
#
# Ross Taylor
#
#
# Quinton de Kock
#
#
# Aaron Finch
#
#
# Jonny Bairstow
#
#
# David Warner
#
#
# Kane Williamson
#
#
# Rassie van der Dussen
#
#
# Josh Hazlewood
#
#
# Chris Woakes
#
#
# Mujeeb Ur Rahman
#
#
# Mehedi Hasan
#
#
# Matt Henry
#
#
# Jasprit Bumrah
#
#
# Mitchell Starc
#
#
# Shakib Al Hasan
#
#
# Andy McBrine
#
#
# Mohammad Nabi
#
#
# Chris Woakes
#
#
# Rashid Khan
#
#
# Mitchell Santner
#
#
# Ben Stokes
#
#
# Colin de Grandhomme
#
#
# Imad Wasim
#
#
# Ravindra Jadeja
#
#
# Jimmy Neesham
#
#
# Virat Kohli
#
#
# Rohit Sharma
#
#
# Ross Taylor
#
#
# Quinton de Kock
#
#
# Aaron Finch
#
#
# Jonny Bairstow
#
#
# David Warner
#
#
# Kane Williamson
#
#
# Rassie van der Dussen
#
#
# Josh Hazlewood
#
#
# Chris Woakes
#
#
# Mujeeb Ur Rahman
#
#
# Mehedi Hasan
#
#
# Matt Henry
#
#
# Jasprit Bumrah
#
#
# Mitchell Starc
#
#
# Shakib Al Hasan
#
#
# Andy McBrine
#
#
# Mohammad Nabi
#
#
# Chris Woakes
#
#
# Rashid Khan
#
#
# Mitchell Santner
#
#
# ...

# %%
Batsmen_Name
# Out:
# ['\nVirat Kohli\n',
#  '\nRohit Sharma\n',
#  '\nRoss Taylor\n',
#  '\nQuinton de Kock\n',
#  '\nAaron Finch\n',
#  '\nJonny Bairstow\n',
#  '\nDavid Warner\n',
#  '\nKane Williamson\n',
#  '\nRassie van der Dussen\n',
#  '\nJosh Hazlewood\n',
#  '\nChris Woakes\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nMehedi Hasan\n',
#  '\nMatt Henry\n',
#  '\nJasprit Bumrah\n',
#  '\nMitchell Starc\n',
#  '\nShakib Al Hasan\n',
#  '\nAndy McBrine\n',
#  '\nMohammad Nabi\n',
#  '\nChris Woakes\n',
#  '\nRashid Khan\n',
#  '\nMitchell Santner\n',
#  '\nBen Stokes\n',
#  '\nColin de Grandhomme\n',
#  '\nImad Wasim\n',
#  '\nRavindra Jadeja\n',
#  '\nJimmy Neesham\n',
#  '\nVirat Kohli\n',
#  '\nRohit Sharma\n',
#  '\nRoss Taylor\n',
#  '\nQuinton de Kock\n',
#  '\nAaron Finch\n',
#  '\nJonny Bairstow\n',
#  '\nDavid Warner\n',
#  '\nKane Williamson\n',
#  '\nRassie van der Dussen\n',
#  '\nJosh Hazlewood\n',
#  '\nChris Woakes\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nMehedi Hasan\n',
#  '\nMatt Henry\n',
# ...

# %%
Batsmen_Name = Batsmen_Name[:9]

# %%
final_list = []
for i in Batsmen_Name:
    final_list.append(i.strip())

# %%
final_list
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Quinton de Kock',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner',
#  'Kane Williamson',
#  'Rassie van der Dussen']

# %%
Team = []
spans = soup7.find_all("span",class_="table-body__logo-text")
for span in spans:
    print(span.text)
    Team.append(span.text)
# Out:
# IND
# IND
# NZ
# SA
# AUS
# ENG
# AUS
# NZ
# SA
# AUS
# ENG
# AFG
# BAN
# NZ
# IND
# AUS
# BAN
# IRE
# AFG
# ENG
# AFG
# NZ
# ENG
# NZ
# PAK
# IND
# NZ
# IND
# IND
# NZ
# SA
# AUS
# ENG
# AUS
# NZ
# SA
# AUS
# ENG
# AFG
# BAN
# NZ
# IND
# AUS
# BAN
# IRE
# AFG
# ENG
# AFG
# NZ
# ENG
# NZ
# PAK
# IND
# NZ

# %%
Team = Team[:9]

# %%
Team
# Out:
# ['IND', 'IND', 'NZ', 'SA', 'AUS', 'ENG', 'AUS', 'NZ', 'SA']

# %%
Rating = []
spans = soup7.find_all("td",class_="table-body__cell u-text-right rating")
for span in spans:
    print(span.text)
    Rating.append(span.text)
# Out:
# 836
# 801
# 801
# 783
# 779
# 775
# 762
# 754
# 750
# 709
# 700
# 697
# 692
# 691
# 689
# 652
# 650
# 646
# 285
# 282
# 268
# 268
# 266
# 257
# 256
# 231
# 226
# 836
# 801
# 801
# 783
# 779
# 775
# 762
# 754
# 750
# 709
# 700
# 697
# 692
# 691
# 689
# 652
# 650
# 646
# 285
# 282
# 268
# 268
# 266
# 257
# 256
# 231
# 226

# %%
Rating = Rating[:9]

# %%
Rating
# Out:
# ['836', '801', '801', '783', '779', '775', '762', '754', '750']

# %%
final_list,Team,Rating
# Out:
# (['Virat Kohli',
#   'Rohit Sharma',
#   'Ross Taylor',
#   'Quinton de Kock',
#   'Aaron Finch',
#   'Jonny Bairstow',
#   'David Warner',
#   'Kane Williamson',
#   'Rassie van der Dussen'],
#  ['IND', 'IND', 'NZ', 'SA', 'AUS', 'ENG', 'AUS', 'NZ', 'SA'],
#  ['836', '801', '801', '783', '779', '775', '762', '754', '750'])

# %%
final_list.insert(0,"Babar Azam")

# %%
Team.insert(0,"PAK")

# %%
Rating.insert(0,865)

# %%
import pandas as pd
ICC_data2 = pd.DataFrame({})
ICC_data2['Team']= Team
ICC_data2['Player_Name']= final_list
ICC_data2['Rating'] = Rating

# %%
ICC_data2
# Out:
#   Team            Player_Name Rating
# 0  PAK             Babar Azam    865
# 1  IND            Virat Kohli    836
# 2  IND           Rohit Sharma    801
# 3   NZ            Ross Taylor    801
# 4   SA        Quinton de Kock    783
# 5  AUS            Aaron Finch    779
# 6  ENG         Jonny Bairstow    775
# 7  AUS           David Warner    762
# 8   NZ        Kane Williamson    754
# 9   SA  Rassie van der Dussen    750

# %% [markdown]
# # iii)Top 10 ODI bowlers along with the records of their team and rating

# %%
Bowler_Name = []
spans = soup7.find_all("td",class_="table-body__cell name")
for span in spans:
    print(span.text)
    Bowler_Name.append(span.text)
# Out:
# Virat Kohli
#
#
# Rohit Sharma
#
#
# Ross Taylor
#
#
# Quinton de Kock
#
#
# Aaron Finch
#
#
# Jonny Bairstow
#
#
# David Warner
#
#
# Kane Williamson
#
#
# Rassie van der Dussen
#
#
# Josh Hazlewood
#
#
# Chris Woakes
#
#
# Mujeeb Ur Rahman
#
#
# Mehedi Hasan
#
#
# Matt Henry
#
#
# Jasprit Bumrah
#
#
# Mitchell Starc
#
#
# Shakib Al Hasan
#
#
# Andy McBrine
#
#
# Mohammad Nabi
#
#
# Chris Woakes
#
#
# Rashid Khan
#
#
# Mitchell Santner
#
#
# Ben Stokes
#
#
# Colin de Grandhomme
#
#
# Imad Wasim
#
#
# Ravindra Jadeja
#
#
# Jimmy Neesham
#
#
# Virat Kohli
#
#
# Rohit Sharma
#
#
# Ross Taylor
#
#
# Quinton de Kock
#
#
# Aaron Finch
#
#
# Jonny Bairstow
#
#
# David Warner
#
#
# Kane Williamson
#
#
# Rassie van der Dussen
#
#
# Josh Hazlewood
#
#
# Chris Woakes
#
#
# Mujeeb Ur Rahman
#
#
# Mehedi Hasan
#
#
# Matt Henry
#
#
# Jasprit Bumrah
#
#
# Mitchell Starc
#
#
# Shakib Al Hasan
#
#
# Andy McBrine
#
#
# Mohammad Nabi
#
#
# Chris Woakes
#
#
# Rashid Khan
#
#
# Mitchell Santner
#
#
# ...

# %%
Bowler_Name[9:18]
# Out:
# ['\nJosh Hazlewood\n',
#  '\nChris Woakes\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nMehedi Hasan\n',
#  '\nMatt Henry\n',
#  '\nJasprit Bumrah\n',
#  '\nMitchell Starc\n',
#  '\nShakib Al Hasan\n',
#  '\nAndy McBrine\n']

# %%
Bowler_Name = Bowler_Name[9:18]

# %%
final_list1 = []
for i in Bowler_Name:
    final_list1.append(i.strip())

# %%
final_list1
# Out:
# ['Josh Hazlewood',
#  'Chris Woakes',
#  'Mujeeb Ur Rahman',
#  'Mehedi Hasan',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mitchell Starc',
#  'Shakib Al Hasan',
#  'Andy McBrine']

# %%
Team1 = []
spans = soup7.find_all("span",class_="table-body__logo-text")
for span in spans:
    print(span.text)
    Team1.append(span.text)
# Out:
# IND
# IND
# NZ
# SA
# AUS
# ENG
# AUS
# NZ
# SA
# AUS
# ENG
# AFG
# BAN
# NZ
# IND
# AUS
# BAN
# IRE
# AFG
# ENG
# AFG
# NZ
# ENG
# NZ
# PAK
# IND
# NZ
# IND
# IND
# NZ
# SA
# AUS
# ENG
# AUS
# NZ
# SA
# AUS
# ENG
# AFG
# BAN
# NZ
# IND
# AUS
# BAN
# IRE
# AFG
# ENG
# AFG
# NZ
# ENG
# NZ
# PAK
# IND
# NZ

# %%
Team1 = Team1[9:18]
Team1
# Out:
# ['AUS', 'ENG', 'AFG', 'BAN', 'NZ', 'IND', 'AUS', 'BAN', 'IRE']

# %%
Rating1 = []
spans = soup7.find_all("td",class_="table-body__cell u-text-right rating")
for span in spans:
    print(span.text)
    Rating1.append(span.text)
# Out:
# 836
# 801
# 801
# 783
# 779
# 775
# 762
# 754
# 750
# 709
# 700
# 697
# 692
# 691
# 689
# 652
# 650
# 646
# 285
# 282
# 268
# 268
# 266
# 257
# 256
# 231
# 226
# 836
# 801
# 801
# 783
# 779
# 775
# 762
# 754
# 750
# 709
# 700
# 697
# 692
# 691
# 689
# 652
# 650
# 646
# 285
# 282
# 268
# 268
# 266
# 257
# 256
# 231
# 226

# %%
Rating1 = Rating1[9:18]
Rating1
# Out:
# ['709', '700', '697', '692', '691', '689', '652', '650', '646']

# %%
final_list1,Team1,Rating1
# Out:
# (['Josh Hazlewood',
#   'Chris Woakes',
#   'Mujeeb Ur Rahman',
#   'Mehedi Hasan',
#   'Matt Henry',
#   'Jasprit Bumrah',
#   'Mitchell Starc',
#   'Shakib Al Hasan',
#   'Andy McBrine'],
#  ['AUS', 'ENG', 'AFG', 'BAN', 'NZ', 'IND', 'AUS', 'BAN', 'IRE'],
#  ['709', '700', '697', '692', '691', '689', '652', '650', '646'])

# %%
final_list1.insert(0,"Trent Boult")
Team1.insert(0,"NZ")
Rating1.insert(0,737)

# %%
import pandas as pd
ICC_data3 = pd.DataFrame({})
ICC_data3['Team']= Team1
ICC_data3['Player_Name']= final_list1
ICC_data3['Rating'] = Rating1
ICC_data3
# Out:
#   Team       Player_Name Rating
# 0   NZ       Trent Boult    737
# 1  AUS    Josh Hazlewood    709
# 2  ENG      Chris Woakes    700
# 3  AFG  Mujeeb Ur Rahman    697
# 4  BAN      Mehedi Hasan    692
# 5   NZ        Matt Henry    691
# 6  IND    Jasprit Bumrah    689
# 7  AUS    Mitchell Starc    652
# 8  BAN   Shakib Al Hasan    650
# 9  IRE      Andy McBrine    646

# %% [markdown]
# # Q6:Write a python program to scrape cricket rankings from ‘www.icccricket.com’ i)Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
Team_data = soup.find_all("div","rankings-block__container full rankings-table")

# %%
Team_name = []

name = soup.find_all("span","u-hide-phablet")
for i in name:
    Team_name.append(i.text)

# %%
Team_name = Team_name[:10]

# %%
Team_name
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'Bangladesh',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Ireland',
#  'Sri Lanka']

# %%
Points_Matches = []

name = soup.find_all("td","table-body__cell u-center-text")
for i in name:
    Points_Matches.append(i.text)

# %%
Points_Matches
# Out:
# ['19',
#  '2,307',
#  '18',
#  '2,148',
#  '17',
#  '1,899',
#  '5',
#  '475',
#  '19',
#  '1,668',
#  '19',
#  '1,658',
#  '19',
#  '1,304',
#  '5',
#  '240',
#  '5',
#  '233',
#  '8',
#  '0']

# %%
Matches = Points_Matches[::2]

# %%
Matches
# Out:
# ['19', '18', '17', '5', '19', '19', '19', '5', '5', '8']

# %%
Points = Points_Matches[1::2]

# %%
Points
# Out:
# ['2,307',
#  '2,148',
#  '1,899',
#  '475',
#  '1,668',
#  '1,658',
#  '1,304',
#  '240',
#  '233',
#  '0']

# %%
Team_name,Matches,Points
# Out:
# (['Australia',
#   'South Africa',
#   'England',
#   'India',
#   'Bangladesh',
#   'New Zealand',
#   'West Indies',
#   'Pakistan',
#   'Ireland',
#   'Sri Lanka'],
#  ['19', '18', '17', '5', '19', '19', '19', '5', '5', '8'],
#  ['2,307',
#   '2,148',
#   '1,899',
#   '475',
#   '1,668',
#   '1,658',
#   '1,304',
#   '240',
#   '233',
#   '0'])

# %%
Rating = []
name = soup.find_all("td","table-body__cell u-text-right rating")
for i in name:
    Rating.append(i.text)

# %%
Rating
# Out:
# ['121', '119', '112', '95', '88', '87', '69', '48', '47', '0']

# %%
import pandas as pd
ICC_data1 = pd.DataFrame({})
ICC_data1['Team_Name']= Team_name
ICC_data1['Matches']= Matches
ICC_data1['Points'] = Points
ICC_data1['Ratings'] = Rating
ICC_data1
# Out:
#       Team_Name Matches Points Ratings
# 0     Australia      19  2,307     121
# 1  South Africa      18  2,148     119
# 2       England      17  1,899     112
# 3         India       5    475      95
# 4    Bangladesh      19  1,668      88
# 5   New Zealand      19  1,658      87
# 6   West Indies      19  1,304      69
# 7      Pakistan       5    240      48
# 8       Ireland       5    233      47
# 9     Sri Lanka       8      0       0

# %% [markdown]
# # ii)Top 10 women’s ODI players along with the records of their team and rating#

# %%
page1 = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")

# %%
page1
# Out:
# <Response [200]>

# %%
soup1 = BeautifulSoup(page1.content)

# %%
soup1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
Team_data1 = soup1.find_all("td","table-body__cell name")
Batswomen_name = []
for i in Team_data1:
    span = i.a.text
    Batswomen_name.append(span)

# %%
Batswomen_name
# Out:
# ['Mithali Raj',
#  'Lizelle Lee',
#  'Tammy Beaumont',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Heather Knight',
#  'Rachael Haynes',
#  'Jhulan Goswami',
#  'Megan Schutt',
#  'Sophie Ecclestone',
#  'Marizanne Kapp',
#  'Shabnim Ismail',
#  'Katherine Brunt',
#  'Ayabonga Khaka',
#  'Anya Shrubsole',
#  'Kate Cross',
#  'Ellyse Perry',
#  'Marizanne Kapp',
#  'Deepti Sharma',
#  'Stafanie Taylor',
#  'Hayley Matthews',
#  'Ashleigh Gardner',
#  'Jess Jonassen',
#  'Katherine Brunt',
#  'Dane van Niekerk']

# %%
Batswomen_Team = []
Team_Name = soup1.find_all("span","table-body__logo-text")

for i in Team_Name:
    Batswomen_Team.append(i.text)

# %%
Batswomen_Team
# Out:
# ['IND',
#  'SA',
#  'ENG',
#  'NZ',
#  'IND',
#  'AUS',
#  'AUS',
#  'ENG',
#  'AUS',
#  'IND',
#  'AUS',
#  'ENG',
#  'SA',
#  'SA',
#  'ENG',
#  'SA',
#  'ENG',
#  'ENG',
#  'AUS',
#  'SA',
#  'IND',
#  'WI',
#  'WI',
#  'AUS',
#  'AUS',
#  'ENG',
#  'SA']

# %%
Batswomen_Rating = []
Rating = soup1.find_all("td","table-body__cell u-text-right rating")

for i in Rating:
    Batswomen_Rating.append(i.text)

# %%
Batswomen_Rating
# Out:
# ['738',
#  '731',
#  '728',
#  '717',
#  '710',
#  '699',
#  '690',
#  '674',
#  '668',
#  '727',
#  '717',
#  '701',
#  '687',
#  '685',
#  '666',
#  '635',
#  '598',
#  '589',
#  '365',
#  '355',
#  '299',
#  '281',
#  '280',
#  '275',
#  '272',
#  '272',
#  '253']

# %%
Batswomen_name = Batswomen_name[:9]
Batswomen_Rating = Batswomen_Rating[:9]
Batswomen_Team = Batswomen_Team[:9]

# %%
Batswomen_name.insert(0,"Tammy Beaumont")

# %%
Batswomen_Rating.insert(0,765)

# %%
Batswomen_Team.insert(0,"ENG")

# %%
import pandas as pd
ICC_data2 = pd.DataFrame({})
ICC_data2['Player_Name']= Batswomen_name
ICC_data2['Team'] = Batswomen_Team
ICC_data2['Rating'] = Batswomen_Rating
ICC_data2
# Out:
#          Player_Name Team Rating
# 0     Tammy Beaumont  ENG    765
# 1     Tammy Beaumont  ENG    765
# 2     Tammy Beaumont  IND    765
# 3     Tammy Beaumont   SA    765
# 4     Tammy Beaumont  ENG    765
# 5        Mithali Raj   NZ    738
# 6        Lizelle Lee  IND    731
# 7     Tammy Beaumont  AUS    728
# 8  Amy Satterthwaite  AUS    717
# 9    Smriti Mandhana  ENG    710

# %% [markdown]
# # iii) Top 10 women’s ODI all-rounder along with the records of their team and rating.#

# %%
Team_data1 = soup1.find_all("td","table-body__cell name")
Allrounder_name = []
for i in Team_data1:
    span = i.a.text
    Allrounder_name.append(span)

# %%
Allrounder_Team = []
Team_Name = soup1.find_all("span","table-body__logo-text")

for i in Team_Name:
    Allrounder_Team.append(i.text)

# %%
Allrounder_Rating = []
Rating = soup1.find_all("td","table-body__cell u-text-right rating")

for i in Rating:
    Allrounder_Rating.append(i.text)

# %%
Allrounder_name
# Out:
# ['Mithali Raj',
#  'Lizelle Lee',
#  'Tammy Beaumont',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Heather Knight',
#  'Rachael Haynes',
#  'Jhulan Goswami',
#  'Megan Schutt',
#  'Sophie Ecclestone',
#  'Marizanne Kapp',
#  'Shabnim Ismail',
#  'Katherine Brunt',
#  'Ayabonga Khaka',
#  'Anya Shrubsole',
#  'Kate Cross',
#  'Ellyse Perry',
#  'Marizanne Kapp',
#  'Deepti Sharma',
#  'Stafanie Taylor',
#  'Hayley Matthews',
#  'Ashleigh Gardner',
#  'Jess Jonassen',
#  'Katherine Brunt',
#  'Dane van Niekerk']

# %%
Allrounder_name = Allrounder_name[-9:]
Allrounder_Rating = Allrounder_Rating[-9:]
Allrounder_Team = Allrounder_Team[-9:]
Allrounder_name.insert(0,"Marizanne Kapp")
Allrounder_Rating.insert(0,418)
Allrounder_Team.insert(0,"SA")

# %%
import pandas as pd
ICC_data3 = pd.DataFrame({})
ICC_data3['Player_Name']= Allrounder_name
ICC_data3['Team'] = Allrounder_Team
ICC_data3['Rating'] = Allrounder_Rating
ICC_data3
# Out:
#         Player_Name Team Rating
# 0    Marizanne Kapp   SA    418
# 1      Ellyse Perry  AUS    365
# 2    Marizanne Kapp   SA    355
# 3     Deepti Sharma  IND    299
# 4   Stafanie Taylor   WI    281
# 5   Hayley Matthews   WI    280
# 6  Ashleigh Gardner  AUS    275
# 7     Jess Jonassen  AUS    272
# 8   Katherine Brunt  ENG    272
# 9  Dane van Niekerk   SA    253

# %% [markdown]
# # Q9: Write a python program to scrape mentioned details from dineout.co.in

# %%
from bs4 import BeautifulSoup
import requests

# %%
page9=requests.get("https://www.dineout.co.in/delhi-restaurants/buffet-special")

# %%
page9
# Out:
# <Response [200]>

# %%
soup9=BeautifulSoup(page9.content)

# %%
soup9
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
rest_name=soup9.find('div',class_="restnt-info cursor")

# %%
rest_name.text
# Out:
# 'Castle BarbequeConnaught Place, Central Delhi'

# %%
location=soup9.find('div',class_="restnt-loc ellipsis")

# %%
location.text
# Out:
# 'Connaught Place, Central Delhi'

# %%
Ratings=[]
for i in soup9.find_all('div',class_="restnt-rating rating-4"):
    Ratings.append(i.text)
    
Ratings
# Out:
# ['3.5',
#  '3.9',
#  '3.9',
#  '4.3',
#  '4',
#  '3.9',
#  '3.7',
#  '3.9',
#  '4.2',
#  '4.3',
#  '3.8',
#  '4.3',
#  '4.1']

# %%
loc=[]
for i in soup9.find_all('div',class_="restnt-loc ellipsis"):
    loc.append(i.text)
    
loc
# Out:
# ['Connaught Place, Central Delhi',
#  '3CS Mall,Lajpat Nagar - 3, South Delhi',
#  'Pacific Mall,Tagore Garden, West Delhi',
#  'The Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  'Gardens Galleria,Sector 38A, Noida',
#  'Hilton Garden Inn,Saket, South Delhi',
#  'Taurus Sarovar Portico,Mahipalpur, South Delhi',
#  'Indirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'Vibe by The Lalit Traveller,Sector 35, Faridabad',
#  'Suncity Business Tower,Golf Course Road, Gurgaon',
#  'Sector 29, Faridabad',
#  'NIT, Faridabad',
#  'DoubleTree By Hilton Gurugram Baani Square,Sector 50, Gurgaon']

# %%
restaurant_name=[]
for i in soup9.find_all('div',class_="restnt-info cursor"):
    restaurant_name.append(i.text)
    
restaurant_name
# Out:
# ['Castle BarbequeConnaught Place, Central Delhi',
#  'Jungle Jamboree3CS Mall,Lajpat Nagar - 3, South Delhi',
#  'Castle BarbequePacific Mall,Tagore Garden, West Delhi',
#  'Cafe KnoshThe Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  'The Barbeque CompanyGardens Galleria,Sector 38A, Noida',
#  'India GrillHilton Garden Inn,Saket, South Delhi',
#  'Delhi BarbequeTaurus Sarovar Portico,Mahipalpur, South Delhi',
#  'The Monarch - Bar Be Que VillageIndirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'World CafeVibe by The Lalit Traveller,Sector 35, Faridabad',
#  'Indian Grill RoomSuncity Business Tower,Golf Course Road, Gurgaon',
#  'Mad 4 Bar B QueSector 29, Faridabad',
#  'Barbeque 29NIT, Faridabad',
#  'GlasshouseDoubleTree By Hilton Gurugram Baani Square,Sector 50, Gurgaon']

# %%
cuisine=soup9.find('span',class_="double-line-ellipsis")

# %%
cuisine.text
# Out:
# '₹ 2,000 for 2 (approx) | North Indian, Chinese'

# %%
cuisine1=[]
for i in soup9.find_all('span',class_="double-line-ellipsis"):
    cuisine1.append(i.text)
    
cuisine1
# Out:
# ['₹ 2,000 for 2 (approx) | North Indian, Chinese',
#  '₹ 1,400 for 2 (approx) | Barbecue, North Indian, Asian, Italian',
#  '₹ 2,000 for 2 (approx) | Chinese, North Indian, Mughlai',
#  '₹ 3,000 for 2 (approx) | Multi-Cuisine, North Indian, Italian, Continental, Mediterranean',
#  '₹ 1,700 for 2 (approx) | North Indian, Barbecue, Chinese, Mughlai',
#  '₹ 2,400 for 2 (approx) | North Indian, Italian, Oriental ',
#  '₹ 1,800 for 2 (approx) | Barbecue, North Indian',
#  '₹ 1,600 for 2 (approx) | North Indian, Chinese, Fast Food',
#  '₹ 900 for 2 (approx) | North Indian, Chinese, Continental',
#  '₹ 2,200 for 2 (approx) | North Indian, Barbecue, Mughlai',
#  '₹ 800 for 2 (approx) | North Indian, Mughlai',
#  '₹ 1,500 for 2 (approx) | North Indian, Chinese, Barbecue',
#  '₹ 3,400 for 2 (approx) | European, Indian Cuisine, Italian, Asian, Continental']

# %%
image=[]
for i in soup9.find_all('img',class_="no-img"):
    image.append(i['data-src'])

image
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/k/b/p86792-16062953735fbe1f4d3fb7e.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/a/k/p59633-16046474755fa4fa33c0e92.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/j/o/p38113-15959192065f1fcb666130c.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/j/v/p406-163401663361651d79326d0.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/q/d/p79307-16051787075fad15532bd7c.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/v/t/p2687-1482477169585cce712b90f.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/v/f/p52501-16006856545f68865616659.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/n/o/p34822-15599107305cfa594a13c24.jpg?tr=tr:n-medium',
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Titles':restaurant_name,'Location':loc,'Cuisine and Price':cuisine1,'Ratings':Ratings,'Images':image})

# %%
df
# Out:
#                                                Titles  \
# 0       Castle BarbequeConnaught Place, Central Delhi
# 1   Jungle Jamboree3CS Mall,Lajpat Nagar - 3, Sout...
# 2   Castle BarbequePacific Mall,Tagore Garden, Wes...
# 3   Cafe KnoshThe Leela Ambience Convention Hotel,...
# 4   The Barbeque CompanyGardens Galleria,Sector 38...
# 5     India GrillHilton Garden Inn,Saket, South Delhi
# 6   Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 7   The Monarch - Bar Be Que VillageIndirapuram Ha...
# 8   World CafeVibe by The Lalit Traveller,Sector 3...
# 9   Indian Grill RoomSuncity Business Tower,Golf C...
# 10                Mad 4 Bar B QueSector 29, Faridabad
# 11                          Barbeque 29NIT, Faridabad
# 12  GlasshouseDoubleTree By Hilton Gurugram Baani ...
#
#                                              Location  \
# 0                      Connaught Place, Central Delhi
# 1              3CS Mall,Lajpat Nagar - 3, South Delhi
# ...

# %% [markdown]
# # Q10 Write a python program to scrape first 10 product details which include product name , price , Image URL from
# https://www.bewakoof.com/women-tshirts?ga_q=tshirts .#

# %%
from bs4 import BeautifulSoup
import requests

# %%
page10=requests.get("https://www.bewakoof.com/women-tshirts?ga_q=tshirts")

# %%
page10
# Out:
# <Response [200]>

# %%
soup10=BeautifulSoup(page10.content)

# %%
soup10
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <link href="https://images.bewakoof.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://images.bewakoof.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://static.bewakoof.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://static.bewakoof.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://cdn.polyfill.io" hreflang="en-in" rel="preconnect"/>
# <link href="https://cdn.polyfill.io" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https//www.googletagmanager.com" hreflang="en-in" rel="preconnect"/>
# <link href="https//www.googletagmanager.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://fonts.gstatic.com" hreflang="en-in" rel="preconnect"/>
# <link href="https://fonts.gstatic.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" hreflang="en-in" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net" hreflang="en-in" rel="dns-prefetch"/>
# ...

# %%
product_name=soup10.find('h3',id="")

# %%
product_name.text
# Out:
# 'Nenu Chepta Nuvvu Half Sleeve T-Shirt'

# %%
price=soup10.find('span',class_="discountedPriceText")

# %%
price.text
# Out:
# '₹ 299'

# %%
image1=[]
for i in soup10.find_all('img',class_="productImgTag"):
    image.append(i['src'])

image1
# Out:
# []

# %% [markdown]
# # Q7 Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content
# and the code for the video from the link for the youtube video from the post

# %%
page11=requests.get("https://coreyms.com/")

# %%
page11
# Out:
# <Response [200]>

# %%
soup11=BeautifulSoup(page11.content)
soup11
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>CoreyMS - Development, Design, DIY, and more</title>
# <meta content="Development, Design, DIY, and more" name="description"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://coreyms.com/" rel="canonical"/>
# <link href="https://coreyms.com/page/2" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="CoreyMS - Development, Design, DIY, and more" property="og:title"/>
# <meta content="Development, Design, DIY, and more" property="og:description"/>
# <meta content="https://coreyms.com/" property="og:url"/>
# <meta content="CoreyMS" property="og:site_name"/>
# ...

# %%
Heading=soup11.find('a',class_="entry-title-link")

# %%
Heading.text
# Out:
# 'Python Tutorial: Zip Files – Creating and Extracting Zip Archives'

# %%
Date=soup11.find('p',class_="entry-meta")

# %%
Date.text
# Out:
# 'November 19, 2019 by Corey Schafer Leave a Comment '

# %%
Content1=soup11.find('div',class_="entry-content")

# %%
Content1.text
# Out:
# '\nIn this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…\n\n'

# %%
link=soup11.find('a',class_="ytp-title-link yt-uix-sessionlink")
